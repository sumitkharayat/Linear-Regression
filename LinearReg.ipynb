# %% [markdown]
# <a href="https://colab.research.google.com/github/sumitkharayat/Linear-Regression/blob/main/LinearReg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# perform linear regression on any other dataset
# Using kaggle as souce of dataset

# %%
import pandas as pd

df = pd.read_csv("crypto2025.12.22.csv")
df.head()
# Out:
#             id symbol      name  current_price     market_cap  \
# 0      bitcoin    btc   Bitcoin   90107.000000  1799491440213
# 1     ethereum    eth  Ethereum    3054.470000   368433368922
# 2       tether   usdt    Tether       0.999626   186759463333
# 3  binancecoin    bnb       BNB     867.680000   119204461497
# 4       ripple    xrp       XRP       1.940000   117231225625
#
#    market_cap_rank  total_volume      high_24h       low_24h  \
# 0                1  3.185549e+10  90096.000000  87655.000000
# 1                2  1.730194e+10   3054.190000   2945.800000
# 2                3  6.103282e+10      0.999879      0.999524
# 3                4  1.077793e+09    867.700000    845.970000
# 4                5  2.147449e+09      1.940000      1.900000
#
#    price_change_percentage_24h  circulating_supply      last_updated
# 0                      1.41837        1.996550e+07  2025-12-22 12:23
# 1                      1.83310        1.206950e+08  2025-12-22 12:23
# ...

# %%
df.columns
# Out:
# Index(['id', 'symbol', 'name', 'current_price', 'market_cap',
#        'market_cap_rank', 'total_volume', 'high_24h', 'low_24h',
#        'price_change_percentage_24h', 'circulating_supply', 'last_updated'],
#       dtype='object')

# %%
X = df['total_volume']
y = df['current_price']

# %% [markdown]
# cleaning the data

# %%
df = df.dropna()

# %%
df.loc[:, 'total_volume'] = pd.to_numeric(df['total_volume'], errors='coerce')
df.loc[:, 'current_price'] = pd.to_numeric(df['current_price'], errors='coerce')

df = df.dropna()

# %%
X = df[['total_volume']]   # 2D
y = df['current_price'] #1D

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)

# %%
import matplotlib.pyplot as plt

plt.scatter(X, y)
plt.plot(X, y_pred)
plt.xlabel("Volume")
plt.ylabel("Price")
plt.title("Linear Regression: Price vs Volume")
plt.show()

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y, y_pred)
print("R² Score:", r2)
# Out:
# R² Score: 0.008691484319064857
